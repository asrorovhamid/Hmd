# %%
#9
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]         #сначала создадим список
for number in numbers:                        #перебор всех эдементов списка с помощью цикла for
    if number < 15:
        odd_numbers.append(number)
print(sorted(odd_numbers))

# %%
#1
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]         #сначала создадим список
for number in numbers:                        #перебор всех эдементов списка с помощью цикла for
    if number % 2 == 1:
        odd_numbers.append(number)
print(sorted(odd_numbers, reverse = True))
# Out:
# [17, 15, 9, 7, 3, 1]

# %%
#7
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]         #сначала создадим список
for number in numbers:                        #перебор всех эдементов списка с помощью цикла for
    if number % 5 == 0:
        odd_numbers.append(number)
print(sorted(odd_numbers, reverse = True))

# %%
#5
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]         #сначала создадим список
for number in numbers:                        #перебор всех эдементов списка с помощью цикла for
    if number > 5:
        odd_numbers.append(number)
print(sorted(odd_numbers))
# Out:
# [7, 8, 9, 15, 17]

# %%
#14
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]         #сначала создадим список
for number in numbers:                        #перебор всех эдементов списка с помощью цикла for
    if number > 9:
        odd_numbers.append(number)
print(sorted(odd_numbers))                #сортировка списки
# Out:
# [15, 17]

# %%
#15
number = [1,2,3,4,-7,-5,-9]
print(sorted(number[1:8:2]))
# Out:
# [-5, 2, 4]

# %%
#13
number = [1,2,3,4,-7,-5,-9]
print(sorted(number[0:8:2], reverse = True))
# Out:
# [3, 1, -7, -9]

# %%
#12
negative_numbers = []
numbers = [1,2,3,4,6,7,-4,-3,-8,-9]
for number in numbers:
    if number < 0:
        negative_numbers.append(number)
print(sorted(negative_numbers))
# Out:
# [-9, -8, -4, -3]

# %%
#2
positive_numbers = []
numbers = [1,2,3,4,6,7,-4,-3,-8,-9]
for number in numbers:
    if number > 0:
        positive_numbers.append(number)
print(sorted(positive_numbers))
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
#3
positive_numbers = []
numbers = [1,2,3,4,6,7,-4,-3,-8,-9]
for number in numbers:
    if number > 0:
        positive_numbers.append(number)
print(sorted(positive_numbers, reverse = True))
# Out:
# [7, 6, 4, 3, 2, 1]

# %%
#4
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]
for number in numbers:
    if number % 2 == 0:
        odd_numbers.append(number)
print(sorted(odd_numbers))
# Out:
# [0, 2, 4, 8]

# %%
#7
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]
for number in numbers:
    if number % 5 == 0:
        odd_numbers.append(number)
print(sorted(odd_numbers, reverse = True))

# %%
#10
odd_numbers = [] 
numbers = [1,2,3,4,7,8,9,0,15,17]
for number in numbers:
    if number % 3 == 0:
        odd_numbers.append(number)
print(sorted(odd_numbers))
# Out:
# [0, 3, 9, 15]
